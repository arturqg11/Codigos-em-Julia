# %%
begin
    using Images
    using ImageFiltering
    using DSP
end
# Out:
#   Cell In[5], line 2
#     using Images
#     ^
# IndentationError: unexpected indent

# %%
imagem_gato = load("Imagens/meowdy.jpg")
# Out:
# 1080×1080 Matrix{RGB{N0f8}}:
#  RGB(0.714, 0.69, 0.643)   …  RGB(0.863, 0.863, 0.824)
#  RGB(0.71, 0.686, 0.639)      RGB(0.859, 0.859, 0.82)
#  RGB(0.71, 0.686, 0.639)      RGB(0.859, 0.859, 0.82)
#  RGB(0.71, 0.686, 0.639)      RGB(0.855, 0.855, 0.816)
#  RGB(0.71, 0.686, 0.639)      RGB(0.855, 0.855, 0.816)
#  RGB(0.71, 0.686, 0.639)   …  RGB(0.851, 0.851, 0.812)
#  RGB(0.706, 0.682, 0.635)     RGB(0.851, 0.851, 0.812)
#  RGB(0.706, 0.682, 0.635)     RGB(0.851, 0.851, 0.812)
#  RGB(0.706, 0.682, 0.635)     RGB(0.851, 0.851, 0.812)
#  RGB(0.706, 0.682, 0.635)     RGB(0.855, 0.855, 0.816)
#  ⋮                         ⋱
#  RGB(0.282, 0.341, 0.353)     RGB(0.859, 0.867, 0.863)
#  RGB(0.286, 0.345, 0.365)     RGB(0.859, 0.863, 0.871)
#  RGB(0.29, 0.349, 0.369)      RGB(0.855, 0.859, 0.867)
#  RGB(0.31, 0.369, 0.388)      RGB(0.855, 0.859, 0.867)
#  RGB(0.337, 0.396, 0.416)  …  RGB(0.855, 0.859, 0.867)
#  RGB(0.353, 0.424, 0.439)     RGB(0.851, 0.855, 0.863)
#  RGB(0.376, 0.447, 0.463)     RGB(0.851, 0.855, 0.863)
#  RGB(0.4, 0.475, 0.49)        RGB(0.855, 0.859, 0.867)
#  RGB(0.427, 0.502, 0.518)     RGB(0.855, 0.859, 0.867)

# %%
size(imagem_gato)
# Out:
# (1080, 1080)

# %%
kernel = Kernel.gaussian((10,10))
# Out:
# 41×41 OffsetArray(::Matrix{Float64}, -20:20, -20:20) with eltype Float64 with indices -20:20×-20:20:
#  3.16486e-5   3.84629e-5   4.62792e-5   …  3.84629e-5   3.16486e-5
#  3.84629e-5   4.67443e-5   5.62436e-5      4.67443e-5   3.84629e-5
#  4.62792e-5   5.62436e-5   6.76734e-5      5.62436e-5   4.62792e-5
#  5.51299e-5   6.7e-5       8.06157e-5      6.7e-5       5.51299e-5
#  6.50199e-5   7.90194e-5   9.50776e-5      7.90194e-5   6.50199e-5
#  7.5921e-5    9.22676e-5   0.000111018  …  9.22676e-5   7.5921e-5
#  8.77677e-5   0.000106665  0.000128341     0.000106665  8.77677e-5
#  0.000100453  0.000122082  0.000146891     0.000122082  0.000100453
#  0.000113829  0.000138337  0.00016645      0.000138337  0.000113829
#  0.000127701  0.000155197  0.000186735     0.000155197  0.000127701
#  ⋮                                      ⋱               ⋮
#  0.000113829  0.000138337  0.00016645      0.000138337  0.000113829
#  0.000100453  0.000122082  0.000146891     0.000122082  0.000100453
#  8.77677e-5   0.000106665  0.000128341     0.000106665  8.77677e-5
#  7.5921e-5    9.22676e-5   0.000111018  …  9.22676e-5   7.5921e-5
#  6.50199e-5   7.90194e-5   9.50776e-5      7.90194e-5   6.50199e-5
#  5.51299e-5   6.7e-5       8.06157e-5      6.7e-5       5.51299e-5
#  4.62792e-5   5.62436e-5   6.76734e-5      5.62436e-5   4.62792e-5
#  3.84629e-5   4.67443e-5   5.62436e-5      4.67443e-5   3.84629e-5
#  3.16486e-5   3.84629e-5   4.62792e-5   …  3.84629e-5   3.16486e-5

# %%
function heatmap_kernel(kernel)
    to_rgb(x) = RGB(max(-x, 0), max(x, 0), 0)
    to_rgb.(kernel) / maximum(abs.(kernel))

end
# Out:
# heatmap_kernel (generic function with 1 method)

# %%
heatmap_kernel(kernel)
# Out:
# 41×41 OffsetArray(::Matrix{RGB{Float64}}, -20:20, -20:20) with eltype RGB{Float64} with indices -20:20×-20:20:
#  RGB(0.0, 0.0183156, 0.0)  …  RGB(0.0, 0.0183156, 0.0)
#  RGB(0.0, 0.0222592, 0.0)     RGB(0.0, 0.0222592, 0.0)
#  RGB(0.0, 0.0267827, 0.0)     RGB(0.0, 0.0267827, 0.0)
#  RGB(0.0, 0.0319048, 0.0)     RGB(0.0, 0.0319048, 0.0)
#  RGB(0.0, 0.0376283, 0.0)     RGB(0.0, 0.0376283, 0.0)
#  RGB(0.0, 0.0439369, 0.0)  …  RGB(0.0, 0.0439369, 0.0)
#  RGB(0.0, 0.0507928, 0.0)     RGB(0.0, 0.0507928, 0.0)
#  RGB(0.0, 0.0581343, 0.0)     RGB(0.0, 0.0581343, 0.0)
#  RGB(0.0, 0.0658748, 0.0)     RGB(0.0, 0.0658748, 0.0)
#  RGB(0.0, 0.0739031, 0.0)     RGB(0.0, 0.0739031, 0.0)
#  ⋮                         ⋱  ⋮
#  RGB(0.0, 0.0658748, 0.0)     RGB(0.0, 0.0658748, 0.0)
#  RGB(0.0, 0.0581343, 0.0)     RGB(0.0, 0.0581343, 0.0)
#  RGB(0.0, 0.0507928, 0.0)     RGB(0.0, 0.0507928, 0.0)
#  RGB(0.0, 0.0439369, 0.0)  …  RGB(0.0, 0.0439369, 0.0)
#  RGB(0.0, 0.0376283, 0.0)     RGB(0.0, 0.0376283, 0.0)
#  RGB(0.0, 0.0319048, 0.0)     RGB(0.0, 0.0319048, 0.0)
#  RGB(0.0, 0.0267827, 0.0)     RGB(0.0, 0.0267827, 0.0)
#  RGB(0.0, 0.0222592, 0.0)     RGB(0.0, 0.0222592, 0.0)
#  RGB(0.0, 0.0183156, 0.0)  …  RGB(0.0, 0.0183156, 0.0)

# %%
imfilter(imagem_gato, kernel)
# Out:
# 1080×1080 Matrix{RGB{Float64}}:
#  RGB(0.715604, 0.684779, 0.631305)  …  RGB(0.856857, 0.856719, 0.817531)
#  RGB(0.715496, 0.684686, 0.631172)     RGB(0.856558, 0.856523, 0.817331)
#  RGB(0.715362, 0.684583, 0.631016)     RGB(0.856241, 0.856326, 0.817172)
#  RGB(0.715217, 0.684471, 0.630846)     RGB(0.855916, 0.856136, 0.817033)
#  RGB(0.71499, 0.684313, 0.630619)      RGB(0.855583, 0.855953, 0.816923)
#  RGB(0.714744, 0.684147, 0.630375)  …  RGB(0.855244, 0.85578, 0.816842)
#  RGB(0.714474, 0.683977, 0.630116)     RGB(0.8549, 0.855622, 0.816788)
#  RGB(0.714181, 0.6838, 0.62984)        RGB(0.854552, 0.855477, 0.816768)
#  RGB(0.713864, 0.683617, 0.629548)     RGB(0.854201, 0.855346, 0.816758)
#  RGB(0.713521, 0.683427, 0.62924)      RGB(0.853861, 0.855241, 0.816795)
#  ⋮                                  ⋱
#  RGB(0.359397, 0.421612, 0.435678)     RGB(0.856991, 0.862955, 0.86236)
#  RGB(0.357914, 0.4217, 0.436018)       RGB(0.856394, 0.862195, 0.862347)
#  RGB(0.356624, 0.421919, 0.436539)     RGB(0.855815, 0.861454, 0.862367)
#  RGB(0.355563, 0.42232, 0.437224)      RGB(0.855258, 0.860737, 0.862382)
#  RGB(0.354751, 0.422914, 0.438084)  …  RGB(0.85473, 0.860053, 0.862425)
#  RGB(0.354199, 0.423707, 0.43912)      RGB(0.854222, 0.859395, 0.86245)
#  RGB(0.353914, 0.424677, 0.440329)     RGB(0.853747, 0.858775, 0.86244)
#  RGB(0.353871, 0.42582, 0.441686)      RGB(0.853314, 0.858206, 0.862439)
#  RGB(0.354053, 0.427112, 0.443164)     RGB(0.852926, 0.857691, 0.862446)

# %%
kernel_2 = [
    -0.5  -1.0  -0.5
    -1.0   7.0  -1.0
    -0.5  -1.0  -0.5
]
# Out:
#   Cell In[6], line 2
#     -0.5  -1.0  -0.5
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
